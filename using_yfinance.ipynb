# %%
import yfinance as yf

# %%
#define the ticker symbol
tickerSymbol1 = 'MSFT'
tickerSymbol2 = 'ETH'
tickerSymbol3 = 'TSLA'
tickerSymbol4 = 'FB'
tickerSymbol5 = 'C'

print(f'You are investing in {tickerSymbol1}, {tickerSymbol2}, {tickerSymbol3}, {tickerSymbol4}, {tickerSymbol5}')
# Out:
# You are investing in MSFT, ETH, TSLA, FB, C

# %%
#get data on this ticker
tickerData = yf.Ticker(tickerSymbol5)
tickerData
# Out:
# yfinance.Ticker object <ETH>

# %%
#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2011-5-1', end='2021-5-1')

# %%
#see your data
tickerDf.tail()
# Out:
#              Open       High        Low      Close  Volume  Dividends  \
# Date
# 2021-04-26  28.91  29.740000  28.430000  28.760000  400100        0.0
# 2021-04-27  28.76  29.120001  28.670000  28.920000  370600        0.0
# 2021-04-28  29.68  31.620001  29.389999  31.490000  953000        0.0
# 2021-04-29  31.52  31.900000  30.700001  30.940001  397800        0.0
# 2021-04-30  30.66  30.700001  28.000000  28.709999  794200        0.0
#
#             Stock Splits
# Date
# 2021-04-26             0
# 2021-04-27             0
# 2021-04-28             0
# 2021-04-29             0
# 2021-04-30             0

# %%
tickerData.recommendations
# Out:
#                                       Firm        To Grade      From Grade  \
# Date
# 2012-04-25 07:56:00        Stifel Nicolaus             Buy
# 2012-12-14 08:06:09        Stifel Nicolaus            Hold             Buy
# 2013-06-04 12:45:52              Dougherty             Buy
# 2014-01-10 08:30:00        Dougherty & Co.         Neutral             Buy
# 2014-06-02 09:32:28    Barrington Research  Market Perform
# 2014-06-09 06:15:18          Gabelli & Co.             Buy
# 2014-07-17 10:30:00                 Nomura         Neutral
# 2014-11-14 09:00:00                 Nomura         Neutral
# 2015-03-25 09:17:50          Gabelli & Co.            Hold             Buy
# 2015-04-15 09:00:00                 Nomura         Neutral
# 2015-04-24 09:29:35           Sidoti & Co.         Neutral             Buy
# 2016-07-27 06:19:07          Raymond James  Market Perform      Outperform
# 2017-01-26 15:34:54              Dougherty         Neutral             Buy
# ...

# %%
data = yf.download("SPY AAPL", start="2011-05-01", end="2021-05-01")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data1 = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "TSLA AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "3mo",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data1 = data1.dropna
data1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-903c868bf464> in <module>
# ----> 1 data1 = data1.dropna
#       2 data1
#
# AttributeError: 'function' object has no attribute 'dropna'
